# %% [markdown]
# # Example inference notebook\n\nUse this notebook to load the backend functions and run inference on pairs of images.

# %%
from backend.inference import run_inference_on_pair\n\n# load images as bytes and call run_inference_on_pair(template_bytes, test_bytes)
