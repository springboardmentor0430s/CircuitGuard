# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/dataset.pcb.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/dataset.pcb.zip
#    creating: /content/dataset.pcb/images/
#    creating: /content/dataset.pcb/images/train/
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_01.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_02.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_04.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_05.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_06.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_07.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_08.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_10.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_11.jpg
#   inflating: /content/dataset.pcb/images/train/01_missing_hole_13.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17739, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 17739 (delta 57), reused 31 (delta 31), pack-reused 17643 (from 4)
# Receiving objects: 100% (17739/17739), 17.16 MiB | 19.96 MiB/s, done.
# Resolving deltas: 100% (12047/12047), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.1 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 20 --data dataset.yaml --weights yolov5n.pt --cache --name run
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-11-18 13:19:58.865158: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763471998.903714    2554 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763471998.917213    2554 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763471998.952614    2554 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 20 --data dataset.yaml --weights yolov5n.pt --cache --name run
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory
